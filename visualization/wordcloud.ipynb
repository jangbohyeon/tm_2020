# %%
voca_appear_20200801 = dtm_20200801.sum()
voca = voca_appear_20200801.sort_values(ascending=False)

# %%
#딕셔너리 형태로 빈도수 정렬하기
word_count = dtm_20200801.sum()
word_dict = dict(word_count)

# %%
#시각화
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
#from nltk.corpus import stopwords
import stylecloud
import numpy as np
from PIL import Image

# %%
mask = np.array(Image.open('image.jpg'))

# %%
stopwords=set(STOPWORDS)
stopwords.add('었다')
stopwords.add('동')
stopwords.add('니')

wc = WordCloud(mask=mask, stopwords=stopwords, max_font_size=100,max_words=40, background_color="white", font_path='home/u1019/tm_2020/data_files/NanumBarunGothic.ttf')
plt.imshow(wc.generate_from_frequencies(word_dict), interpolation="bilinear")
plt.axis("off")
